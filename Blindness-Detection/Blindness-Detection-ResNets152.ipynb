# %% [markdown]
# In this notebook, we'll use the following techniques to train a state-of-the-art model in classifying images from the Blindness dataset:
#
# - Data normalization
# - Data augmentation
# - Residual connections
# - Batch normalization
# - Learning rate scheduling
# - Weight Decay
# - Gradient clipping
# - Adam optimizer

# %% [markdown]
# ## Importing the required libraries

# %%
import os
import torch
import torchvision
import pandas as pd
import torch.nn as nn
from PIL import Image
import cv2
import numpy as np
import torch.nn.functional as F
import torchvision.transforms as tt
from torchvision.utils import make_grid
from torch.utils.data import DataLoader
from torch.utils.data import random_split
from torch.utils.data.sampler import SubsetRandomSampler
import torchvision.models as models # Pre-Trained models
import sklearn
from sklearn.metrics import cohen_kappa_score, accuracy_score
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

matplotlib.rcParams['figure.facecolor'] = '#ffffff'

# %% [markdown]
# ## Loading Dataset + EDA

# %%
# !pip install opendatasets
# Out:
# Requirement already satisfied: opendatasets in /usr/local/lib/python3.7/dist-packages (0.1.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from opendatasets) (4.41.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from opendatasets) (7.1.2)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (from opendatasets) (1.5.10)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2.23.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2.8.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (1.24.3)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (4.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2020.12.5)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle->opendatasets) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle->opendatasets) (3.0.4)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)

# %%
import opendatasets as od

# %%
dataset_url = 'https://www.kaggle.com/c/aptos2019-blindness-detection'

od.download(dataset_url, '.')
# Out:
#   0%|          | 9.00M/9.51G [00:00<01:57, 87.1MB/s]
# Downloading aptos2019-blindness-detection.zip to ./aptos2019-blindness-detection
# 100%|██████████| 9.51G/9.51G [03:43<00:00, 45.6MB/s]

# %%
# !wget https://www.kaggle.com/c/aptos2019-blindness-detection
# Out:
# --2021-03-13 10:28:29--  https://www.kaggle.com/c/aptos2019-blindness-detection
# Resolving www.kaggle.com (www.kaggle.com)... 35.244.233.98
# Connecting to www.kaggle.com (www.kaggle.com)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘aptos2019-blindness-detection’
#
# aptos2019-blindness     [ <=>                ]  55.89K  --.-KB/s    in 0.002s
#
# 2021-03-13 10:28:29 (33.6 MB/s) - ‘aptos2019-blindness-detection’ saved [57234]

# %%
# !unzip '/content/aptos2019-blindness-detection/aptos2019-blindness-detection.zip' -d '/content/aptos2019-blindness-detection'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/aptos2019-blindness-detection/test_images/512beaada8f0.png
#   inflating: /content/aptos2019-blindness-detection/test_images/51323e9d2070.png
#   inflating: /content/aptos2019-blindness-detection/test_images/515675001b9e.png
#   inflating: /content/aptos2019-blindness-detection/test_images/515877da2def.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5168ddccea88.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5172c056a687.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5177461f5339.png
#   inflating: /content/aptos2019-blindness-detection/test_images/51910bcb980d.png
#   inflating: /content/aptos2019-blindness-detection/test_images/51a3e9b6a1c0.png
#   inflating: /content/aptos2019-blindness-detection/test_images/51bbd82feec8.png
#   inflating: /content/aptos2019-blindness-detection/test_images/51de5fb8eccd.png
#   inflating: /content/aptos2019-blindness-detection/test_images/51e88694c81f.png
#   inflating: /content/aptos2019-blindness-detection/test_images/51f0bf8f1544.png
#   inflating: /content/aptos2019-blindness-detection/test_images/51f57fb32840.png
#   inflating: /content/aptos2019-blindness-detection/test_images/51fa42dc1415.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5276ab33b7b0.png
#   inflating: /content/aptos2019-blindness-detection/test_images/52a353760f72.png
#   inflating: /content/aptos2019-blindness-detection/test_images/531937254e73.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5325b1c22c61.png
#   inflating: /content/aptos2019-blindness-detection/test_images/53959e0a750b.png
#   inflating: /content/aptos2019-blindness-detection/test_images/53be22c72713.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5400549bfe76.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5416642e06dd.png
#   inflating: /content/aptos2019-blindness-detection/test_images/54377de41c97.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5450ee92dfc6.png
#   inflating: /content/aptos2019-blindness-detection/test_images/54b6b91249ad.png
#   inflating: /content/aptos2019-blindness-detection/test_images/551f1e4e2763.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5544449ac18d.png
#   inflating: /content/aptos2019-blindness-detection/test_images/556c2790a2e5.png
#   inflating: /content/aptos2019-blindness-detection/test_images/557be0cf8e49.png
#   inflating: /content/aptos2019-blindness-detection/test_images/558664213d06.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5595883f47f0.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5598165adbff.png
#   inflating: /content/aptos2019-blindness-detection/test_images/559a719e403f.png
#   inflating: /content/aptos2019-blindness-detection/test_images/55ab23df5fa0.png
#   inflating: /content/aptos2019-blindness-detection/test_images/55bae08492c0.png
#   inflating: /content/aptos2019-blindness-detection/test_images/55c5356d96f8.png
#   inflating: /content/aptos2019-blindness-detection/test_images/567bfbf30117.png
#   inflating: /content/aptos2019-blindness-detection/test_images/56ad22ef1012.png
#   inflating: /content/aptos2019-blindness-detection/test_images/56ef3b79e31f.png
#   inflating: /content/aptos2019-blindness-detection/test_images/570982b0dbf2.png
#   inflating: /content/aptos2019-blindness-detection/test_images/571ab04c9e87.png
#   inflating: /content/aptos2019-blindness-detection/test_images/57327f5c7d71.png
#   inflating: /content/aptos2019-blindness-detection/test_images/57cbd5909e16.png
#   inflating: /content/aptos2019-blindness-detection/test_images/57d5d0d42cac.png
#   inflating: /content/aptos2019-blindness-detection/test_images/57e7e85b6bcd.png
#   inflating: /content/aptos2019-blindness-detection/test_images/57fa1bc682b6.png
#   inflating: /content/aptos2019-blindness-detection/test_images/58392bb56fad.png
#   inflating: /content/aptos2019-blindness-detection/test_images/584dab56f2c5.png
#   inflating: /content/aptos2019-blindness-detection/test_images/586eba507c88.png
#   inflating: /content/aptos2019-blindness-detection/test_images/587e6a83a90f.png
#   inflating: /content/aptos2019-blindness-detection/test_images/589747aab826.png
#   inflating: /content/aptos2019-blindness-detection/test_images/58a536e6fdde.png
#   inflating: /content/aptos2019-blindness-detection/test_images/58a569759348.png
#   inflating: /content/aptos2019-blindness-detection/test_images/58ab162bfc89.png
#   inflating: /content/aptos2019-blindness-detection/test_images/58b740608ded.png
#   inflating: /content/aptos2019-blindness-detection/test_images/58d6d0115c72.png
#   inflating: /content/aptos2019-blindness-detection/test_images/58ec1c8ed8b1.png
#   inflating: /content/aptos2019-blindness-detection/test_images/58f0807d2297.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5953417e4750.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5971c10c1465.png
#   inflating: /content/aptos2019-blindness-detection/test_images/59738e82c527.png
#   inflating: /content/aptos2019-blindness-detection/test_images/597ab119ba6d.png
#   inflating: /content/aptos2019-blindness-detection/test_images/59abc465e159.png
#   inflating: /content/aptos2019-blindness-detection/test_images/59e7f9e69044.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5a1dd8fa44e9.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5a311e3e8979.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5a66a5abdec6.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5a6a2c8cdd35.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5a8dbaf0e001.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5ab71d422459.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5ab9e78b45ef.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5ad2ca6d422f.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5ad469f293f7.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5add6f0b6b82.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5b04aa895c31.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5b18feb15d84.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5b27368c6983.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5b42aa87662e.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5b79366b7eb0.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5b7aec374735.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5b7e38adccf3.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5b81f6394a99.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5b931245433c.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5baaa0041555.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5bd9e507ed71.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5c081b9e1c7f.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5c1ed0268157.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5c3872c226bb.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5ca89ec3c507.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5cbc7df5a21c.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5cfc10f6114c.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5d26d29704ad.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5d2e1e53b383.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5d3d0306074c.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5d3f125976eb.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5d443c9e3d39.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5d62c37386fc.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5d6b9a2fddbf.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5d97ebd575cd.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5db032900d31.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5db5832b333b.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5dc52ff46300.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5de19dac4ac3.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5de413ba9250.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5ea81ad2e8f2.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5ebc9dbbe79d.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5ed96c970a57.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5edf6828c280.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5f06b715ea24.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5f158adf5bbc.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5f4dec014acf.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5f84992353f8.png
#   inflating: /content/aptos2019-blindness-detection/test_images/5fa2f89a0ec2.png
#   inflating: /content/aptos2019-blindness-detection/test_images/600afae2d4e9.png
#   inflating: /content/aptos2019-blindness-detection/test_images/600b2b469a2f.png
#   inflating: /content/aptos2019-blindness-detection/test_images/605359a98377.png
#   inflating: /content/aptos2019-blindness-detection/test_images/607f40adf8b1.png
#   inflating: /content/aptos2019-blindness-detection/test_images/60849fa4a14a.png
#   inflating: /content/aptos2019-blindness-detection/test_images/60c6583fa35c.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6124e6a4ad00.png
#   inflating: /content/aptos2019-blindness-detection/test_images/616a989990b0.png
#   inflating: /content/aptos2019-blindness-detection/test_images/619ce2c77917.png
#   inflating: /content/aptos2019-blindness-detection/test_images/61cd9c25c7d3.png
#   inflating: /content/aptos2019-blindness-detection/test_images/61ddbcedbc9e.png
#   inflating: /content/aptos2019-blindness-detection/test_images/61ff3873c036.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6220b43ea8eb.png
#   inflating: /content/aptos2019-blindness-detection/test_images/624ebaffb2ab.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6263433f1991.png
#   inflating: /content/aptos2019-blindness-detection/test_images/626fe00f5cf7.png
#   inflating: /content/aptos2019-blindness-detection/test_images/627997ab6ba3.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6290dba05950.png
#   inflating: /content/aptos2019-blindness-detection/test_images/62917dbb7858.png
#   inflating: /content/aptos2019-blindness-detection/test_images/62d9da36bd9e.png
#   inflating: /content/aptos2019-blindness-detection/test_images/62df7040b3df.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6356f9dd9fdc.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6365da11bf72.png
#   inflating: /content/aptos2019-blindness-detection/test_images/636997a49fcb.png
#   inflating: /content/aptos2019-blindness-detection/test_images/63826c56eeac.png
#   inflating: /content/aptos2019-blindness-detection/test_images/638a49bc4928.png
#   inflating: /content/aptos2019-blindness-detection/test_images/63dd40d7439b.png
#   inflating: /content/aptos2019-blindness-detection/test_images/63f3c188ccb6.png
#   inflating: /content/aptos2019-blindness-detection/test_images/63f6b0fe5bbf.png
#   inflating: /content/aptos2019-blindness-detection/test_images/643ff5d1f90f.png
#   inflating: /content/aptos2019-blindness-detection/test_images/644f1ba18d8b.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6466e474e048.png
#   inflating: /content/aptos2019-blindness-detection/test_images/64a4926e85b5.png
#   inflating: /content/aptos2019-blindness-detection/test_images/64a507309332.png
#   inflating: /content/aptos2019-blindness-detection/test_images/64d749faea54.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6508c11c4785.png
#   inflating: /content/aptos2019-blindness-detection/test_images/65153f9ad387.png
#   inflating: /content/aptos2019-blindness-detection/test_images/652a1edabdb7.png
#   inflating: /content/aptos2019-blindness-detection/test_images/652a7d1e42cf.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6543b4168f98.png
#   inflating: /content/aptos2019-blindness-detection/test_images/657b8609f26f.png
#   inflating: /content/aptos2019-blindness-detection/test_images/659f752cb810.png
#   inflating: /content/aptos2019-blindness-detection/test_images/65cf08a0ecc8.png
#   inflating: /content/aptos2019-blindness-detection/test_images/662785685674.png
#   inflating: /content/aptos2019-blindness-detection/test_images/66304c1099a0.png
#   inflating: /content/aptos2019-blindness-detection/test_images/667ec71b5003.png
#   inflating: /content/aptos2019-blindness-detection/test_images/66bce216e103.png
#   inflating: /content/aptos2019-blindness-detection/test_images/67b614d32bcc.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6825ccf0affe.png
#   inflating: /content/aptos2019-blindness-detection/test_images/682baef89ab6.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6833ab2550c9.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6853d1c8546d.png
#   inflating: /content/aptos2019-blindness-detection/test_images/687856bd64a7.png
#   inflating: /content/aptos2019-blindness-detection/test_images/68823df37247.png
#   inflating: /content/aptos2019-blindness-detection/test_images/688ae4721ccd.png
#   inflating: /content/aptos2019-blindness-detection/test_images/689d028fe647.png
#   inflating: /content/aptos2019-blindness-detection/test_images/689d5626e98a.png
#   inflating: /content/aptos2019-blindness-detection/test_images/68a6c5d949f5.png
#   inflating: /content/aptos2019-blindness-detection/test_images/68aa38df13d5.png
#   inflating: /content/aptos2019-blindness-detection/test_images/68d97772bd3a.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6938b334d93b.png
#   inflating: /content/aptos2019-blindness-detection/test_images/697fb916ad18.png
#   inflating: /content/aptos2019-blindness-detection/test_images/69b3f1028e99.png
#   inflating: /content/aptos2019-blindness-detection/test_images/69bf0233198e.png
#   inflating: /content/aptos2019-blindness-detection/test_images/69d21c5c7dce.png
#   inflating: /content/aptos2019-blindness-detection/test_images/69f0ca93349a.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6a0f21edb0d8.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6a1ee951c1d5.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6a27a25f7a0c.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6a4936e83256.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6a4a51e42782.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6a4ab4927ee7.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6a54653ad12b.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6a6b6dc586c8.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6ad7b5beef75.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6ae0afd18f89.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6aecc3aa2de7.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6afb888c1c74.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6b26135a16f1.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6b62d4aae182.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6b7d26aea1e9.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6c3053baeb67.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6c96703bc565.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6d0df0ec5fd7.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6d41b03ce069.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6d51db325a98.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6d7f586a4f82.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6dce3f20de26.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6dd2dbd802ea.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6e19f08344ed.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6e239ecaad8d.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6e2d7cee2d91.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6e2f3f746226.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6e48f854f7e6.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6e56361bbd36.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6e5887ae04c7.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6ea2fc471536.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6eb52b81fa50.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6ec54031d7ca.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6ed92d0b2f78.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6ed9e38a4239.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6ef23497ea54.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6f275262123c.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6f43a3d1ed0a.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6f5f99d0480c.png
#   inflating: /content/aptos2019-blindness-detection/test_images/6f8a7b6b30c2.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7007d3ba7e79.png
#   inflating: /content/aptos2019-blindness-detection/test_images/70115c0f75cf.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7015c532679c.png
#   inflating: /content/aptos2019-blindness-detection/test_images/701ac49e32d2.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7031ca7c5ee1.png
#   inflating: /content/aptos2019-blindness-detection/test_images/704c6f80bb20.png
#   inflating: /content/aptos2019-blindness-detection/test_images/70a51d863a5e.png
#   inflating: /content/aptos2019-blindness-detection/test_images/70f660f46630.png
#   inflating: /content/aptos2019-blindness-detection/test_images/71047d5e7299.png
#   inflating: /content/aptos2019-blindness-detection/test_images/71291389a55d.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7136203550af.png
#   inflating: /content/aptos2019-blindness-detection/test_images/716b001ba7a4.png
#   inflating: /content/aptos2019-blindness-detection/test_images/71d124893573.png
#   inflating: /content/aptos2019-blindness-detection/test_images/71eba9a97184.png
#   inflating: /content/aptos2019-blindness-detection/test_images/720267b6630b.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7205b4cbc184.png
#   inflating: /content/aptos2019-blindness-detection/test_images/724929cecee3.png
#   inflating: /content/aptos2019-blindness-detection/test_images/724afd41a9fa.png
#   inflating: /content/aptos2019-blindness-detection/test_images/72b8b473ffbd.png
#   inflating: /content/aptos2019-blindness-detection/test_images/72dd7ca97f55.png
#   inflating: /content/aptos2019-blindness-detection/test_images/732aa8f82078.png
#   inflating: /content/aptos2019-blindness-detection/test_images/73894f64bcb1.png
#   inflating: /content/aptos2019-blindness-detection/test_images/73a0917d732b.png
#   inflating: /content/aptos2019-blindness-detection/test_images/73b897339735.png
#   inflating: /content/aptos2019-blindness-detection/test_images/741ef20e5e28.png
#   inflating: /content/aptos2019-blindness-detection/test_images/74342f5181a9.png
#   inflating: /content/aptos2019-blindness-detection/test_images/74350fe494ba.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7454c19acf81.png
#   inflating: /content/aptos2019-blindness-detection/test_images/74b0edef5063.png
#   inflating: /content/aptos2019-blindness-detection/test_images/74b5ba54d7cc.png
#   inflating: /content/aptos2019-blindness-detection/test_images/74c97e963ca4.png
#   inflating: /content/aptos2019-blindness-detection/test_images/74df1775ee07.png
#   inflating: /content/aptos2019-blindness-detection/test_images/74fbfe8eefd2.png
#   inflating: /content/aptos2019-blindness-detection/test_images/755615db51d3.png
#   inflating: /content/aptos2019-blindness-detection/test_images/75b6ffa63525.png
#   inflating: /content/aptos2019-blindness-detection/test_images/75bca27c127d.png
#   inflating: /content/aptos2019-blindness-detection/test_images/75c6563ed058.png
#   inflating: /content/aptos2019-blindness-detection/test_images/75d1e729c75d.png
#   inflating: /content/aptos2019-blindness-detection/test_images/760f9f1cf5c2.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7614373a95a0.png
#   inflating: /content/aptos2019-blindness-detection/test_images/762107ec466c.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7635124f70f8.png
#   inflating: /content/aptos2019-blindness-detection/test_images/763bfd250520.png
#   inflating: /content/aptos2019-blindness-detection/test_images/764b9b51cd9f.png
#   inflating: /content/aptos2019-blindness-detection/test_images/764e6ea355ac.png
#   inflating: /content/aptos2019-blindness-detection/test_images/767cf5fccd97.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7690663d8171.png
#   inflating: /content/aptos2019-blindness-detection/test_images/76a1bc72e45f.png
#   inflating: /content/aptos2019-blindness-detection/test_images/76b15ed2d4be.png
#   inflating: /content/aptos2019-blindness-detection/test_images/76c854fde95e.png
#   inflating: /content/aptos2019-blindness-detection/test_images/76d8e779d555.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7715276d2551.png
#   inflating: /content/aptos2019-blindness-detection/test_images/77283954f311.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7744ab973027.png
#   inflating: /content/aptos2019-blindness-detection/test_images/774cafde22b5.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7754a10b07ae.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7764e684c8d4.png
#   inflating: /content/aptos2019-blindness-detection/test_images/77978316c53a.png
#   inflating: /content/aptos2019-blindness-detection/test_images/779f70ddc126.png
#   inflating: /content/aptos2019-blindness-detection/test_images/77cf0d228a12.png
#   inflating: /content/aptos2019-blindness-detection/test_images/77f1ffe777b7.png
#   inflating: /content/aptos2019-blindness-detection/test_images/782cdccbdb1a.png
#   inflating: /content/aptos2019-blindness-detection/test_images/783b3787c36d.png
#   inflating: /content/aptos2019-blindness-detection/test_images/78747a58eabc.png
#   inflating: /content/aptos2019-blindness-detection/test_images/78816c91ac9a.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7889e79f59f6.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7898c981032a.png
#   inflating: /content/aptos2019-blindness-detection/test_images/78bdd1ecee00.png
#   inflating: /content/aptos2019-blindness-detection/test_images/78ce997489a4.png
#   inflating: /content/aptos2019-blindness-detection/test_images/791fbce04aa5.png
#   inflating: /content/aptos2019-blindness-detection/test_images/793ae37853b4.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7959bb5d9fa2.png
#   inflating: /content/aptos2019-blindness-detection/test_images/79726ebe9844.png
#   inflating: /content/aptos2019-blindness-detection/test_images/79adfdcb827f.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7a34808e1e70.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7a4d0a3b5e5a.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7a5b1c716560.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7a75f799ecaf.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7a7f72b1c5ce.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7a9b50cd9a1c.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7ac156fd3932.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7af3af7910a4.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7b03611c6d88.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7b17a0d85204.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7b66133d42cf.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7ba4225b323e.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7baa6e053baf.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7bafbda8b8f7.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7bebe5198246.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7c0748d6d669.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7c0c20cd8114.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7c10eeb5f1ee.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7c1d86c79903.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7ca07d02a1ff.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7d15cfc7fc45.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7d182df47a75.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7d2243c508d8.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7d353a9d3218.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7d593a4da56f.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7d67e38d7ba6.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7d6ea897ee30.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7d747f8387a8.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7d7cbd5ee1b3.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7dcbbc17fe47.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7dfc3db13445.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7e0ec22cb51b.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7e1f51fbb458.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7e5b5318671f.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7eb119b81d16.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7eeed2e26c9f.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7f0920d6072e.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7f3d521363ab.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7f9c86406c62.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7fa21762b1c3.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7fe2cff51752.png
#   inflating: /content/aptos2019-blindness-detection/test_images/7ffecef49237.png
#   inflating: /content/aptos2019-blindness-detection/test_images/805103f04fd6.png
#   inflating: /content/aptos2019-blindness-detection/test_images/808f32272dc8.png
#   inflating: /content/aptos2019-blindness-detection/test_images/80921264504c.png
#   inflating: /content/aptos2019-blindness-detection/test_images/80976eb17462.png
#   inflating: /content/aptos2019-blindness-detection/test_images/80aa9b30d2f9.png
#   inflating: /content/aptos2019-blindness-detection/test_images/80d85db5fe6f.png
#   inflating: /content/aptos2019-blindness-detection/test_images/80ffe924f95b.png
#   inflating: /content/aptos2019-blindness-detection/test_images/810b1ef05d20.png
#   inflating: /content/aptos2019-blindness-detection/test_images/810b9603c241.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8142cc87ebb9.png
#   inflating: /content/aptos2019-blindness-detection/test_images/81a9391f7828.png
#   inflating: /content/aptos2019-blindness-detection/test_images/81ed0c587703.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8208638fc7cf.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8214256b4e51.png
#   inflating: /content/aptos2019-blindness-detection/test_images/82515c8bfd5e.png
#   inflating: /content/aptos2019-blindness-detection/test_images/82566de7f4d1.png
#   inflating: /content/aptos2019-blindness-detection/test_images/828ad210e3e2.png
#   inflating: /content/aptos2019-blindness-detection/test_images/82a412dba6cd.png
#   inflating: /content/aptos2019-blindness-detection/test_images/82cdbde2bd94.png
#   inflating: /content/aptos2019-blindness-detection/test_images/82eecce4cb86.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8305107835c6.png
#   inflating: /content/aptos2019-blindness-detection/test_images/831826087154.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8327efe946c2.png
#   inflating: /content/aptos2019-blindness-detection/test_images/836324a89d99.png
#   inflating: /content/aptos2019-blindness-detection/test_images/836b43b8c125.png
#   inflating: /content/aptos2019-blindness-detection/test_images/83bd9d017f84.png
#   inflating: /content/aptos2019-blindness-detection/test_images/83c31eeeca0e.png
#   inflating: /content/aptos2019-blindness-detection/test_images/83cfacba2dd7.png
#   inflating: /content/aptos2019-blindness-detection/test_images/848091b1f5d0.png
#   inflating: /content/aptos2019-blindness-detection/test_images/84acea0b8a00.png
#   inflating: /content/aptos2019-blindness-detection/test_images/84eff2a86662.png
#   inflating: /content/aptos2019-blindness-detection/test_images/85035afa9b10.png
#   inflating: /content/aptos2019-blindness-detection/test_images/85105e9ab635.png
#   inflating: /content/aptos2019-blindness-detection/test_images/855d60689040.png
#   inflating: /content/aptos2019-blindness-detection/test_images/85601f22d90d.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8571e10b7294.png
#   inflating: /content/aptos2019-blindness-detection/test_images/857e2dafc6d0.png
#   inflating: /content/aptos2019-blindness-detection/test_images/85ceca982305.png
#   inflating: /content/aptos2019-blindness-detection/test_images/85f608bcb50a.png
#   inflating: /content/aptos2019-blindness-detection/test_images/862cc91ef3f0.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8634cfaa63c5.png
#   inflating: /content/aptos2019-blindness-detection/test_images/86683eb8921e.png
#   inflating: /content/aptos2019-blindness-detection/test_images/86c179395e2b.png
#   inflating: /content/aptos2019-blindness-detection/test_images/86ca8c8d563d.png
#   inflating: /content/aptos2019-blindness-detection/test_images/86fd5df366b2.png
#   inflating: /content/aptos2019-blindness-detection/test_images/87252c491c19.png
#   inflating: /content/aptos2019-blindness-detection/test_images/872d2097a7ad.png
#   inflating: /content/aptos2019-blindness-detection/test_images/87487c4c4ddc.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8750b8bfe28a.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8798cccbcb0d.png
#   inflating: /content/aptos2019-blindness-detection/test_images/880eacc5ab23.png
#   inflating: /content/aptos2019-blindness-detection/test_images/881ab102a44e.png
#   inflating: /content/aptos2019-blindness-detection/test_images/881c69e5dcd8.png
#   inflating: /content/aptos2019-blindness-detection/test_images/887b4413f87c.png
#   inflating: /content/aptos2019-blindness-detection/test_images/88e0bd76f4c9.png
#   inflating: /content/aptos2019-blindness-detection/test_images/88fda3e06e05.png
#   inflating: /content/aptos2019-blindness-detection/test_images/890dd0b1921b.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8914493483f5.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8927a914c9c8.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8930d35c9076.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8938eb4d9c63.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8939b6701f96.png
#   inflating: /content/aptos2019-blindness-detection/test_images/893b140bd358.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8943b2b8c8ea.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8944ffa47333.png
#   inflating: /content/aptos2019-blindness-detection/test_images/896c75533897.png
#   inflating: /content/aptos2019-blindness-detection/test_images/898232c36d81.png
#   inflating: /content/aptos2019-blindness-detection/test_images/89a37093baa9.png
#   inflating: /content/aptos2019-blindness-detection/test_images/89f1314e2c10.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8a177340ac5a.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8a1791bd2bb0.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8a2b969112a7.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8aba1a000d36.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8adf13f4fc16.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8ae672ef2f60.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8afe0b63efa5.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8affa9a1fecd.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8b27d742f971.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8b83f4b2d1a9.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8b840ed255d8.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8b96e506768c.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8bb4dfa61806.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8bbef4ac9702.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8bdd17b5974b.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8bdd3a1895c8.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8c0f725874af.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8c41de06d44e.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8c45490f701a.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8c49d9de02d6.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8c4b2c26e478.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8c4bb8e93f24.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8c6ccbe00895.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8c9cf6f116be.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8ca8da22d961.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8cbefbaed16e.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8cf4258bd346.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8cfa1b047c34.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8cfe2de3e7f4.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8d01494c2821.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8d0bcd4ebff6.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8d72498b9e30.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8d892f6b5976.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8d955a3d9286.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8daed4c00661.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8dc530ad4a1e.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8dd1c698ae62.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8e4cf64ec035.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8e83a8ae27cf.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8ea5698a1619.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8eec629c3c8b.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8efd5ed7c4d8.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8f4612fa90aa.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8f4ffa0d4f74.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8f874a9724df.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8fb196f59171.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8fc5d55a4ece.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8fc74bd50fcb.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8fcc91d6e28f.png
#   inflating: /content/aptos2019-blindness-detection/test_images/8fdecd6a923d.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9003ab48ebb8.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9006234e30cf.png
#   inflating: /content/aptos2019-blindness-detection/test_images/901028c2b54f.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9031d62a6efb.png
#   inflating: /content/aptos2019-blindness-detection/test_images/90c98069e6f1.png
#   inflating: /content/aptos2019-blindness-detection/test_images/90f3a3addf92.png
#   inflating: /content/aptos2019-blindness-detection/test_images/90fc89319207.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9156e3f3a878.png
#   inflating: /content/aptos2019-blindness-detection/test_images/91705661f6a8.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9193a240b495.png
#   inflating: /content/aptos2019-blindness-detection/test_images/91b81018ff9d.png
#   inflating: /content/aptos2019-blindness-detection/test_images/91cb9f86e456.png
#   inflating: /content/aptos2019-blindness-detection/test_images/91fb0a2a63fd.png
#   inflating: /content/aptos2019-blindness-detection/test_images/91fc4b2b8c1c.png
#   inflating: /content/aptos2019-blindness-detection/test_images/91fd830b7677.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9215a3ce482b.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9240b949fdc0.png
#   inflating: /content/aptos2019-blindness-detection/test_images/925967c408c7.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9266068354b4.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9285ad837947.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9295bc2a4c7a.png
#   inflating: /content/aptos2019-blindness-detection/test_images/929ae04a77a9.png
#   inflating: /content/aptos2019-blindness-detection/test_images/92c773457ab2.png
#   inflating: /content/aptos2019-blindness-detection/test_images/92eb43fbfd8b.png
#   inflating: /content/aptos2019-blindness-detection/test_images/92ebf5417491.png
#   inflating: /content/aptos2019-blindness-detection/test_images/92f5e1793a37.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9305aafdde3d.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9311beca06a7.png
#   inflating: /content/aptos2019-blindness-detection/test_images/93220677378c.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9324f4ff95d2.png
#   inflating: /content/aptos2019-blindness-detection/test_images/933724df128e.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9375f39522ab.png
#   inflating: /content/aptos2019-blindness-detection/test_images/938a59f04582.png
#   inflating: /content/aptos2019-blindness-detection/test_images/93aa0b383db9.png
#   inflating: /content/aptos2019-blindness-detection/test_images/93b480980afb.png
#   inflating: /content/aptos2019-blindness-detection/test_images/93c1af8b625c.png
#   inflating: /content/aptos2019-blindness-detection/test_images/93cbafc82f37.png
#   inflating: /content/aptos2019-blindness-detection/test_images/94017cfa574e.png
#   inflating: /content/aptos2019-blindness-detection/test_images/94281fced6bb.png
#   inflating: /content/aptos2019-blindness-detection/test_images/944678405e5e.png
#   inflating: /content/aptos2019-blindness-detection/test_images/948c75fbe02f.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9496a9b6c38e.png
#   inflating: /content/aptos2019-blindness-detection/test_images/94a6e4f3c625.png
#   inflating: /content/aptos2019-blindness-detection/test_images/94fac9bf79e0.png
#   inflating: /content/aptos2019-blindness-detection/test_images/95485b752436.png
#   inflating: /content/aptos2019-blindness-detection/test_images/95753b394d4c.png
#   inflating: /content/aptos2019-blindness-detection/test_images/95838f27bb23.png
#   inflating: /content/aptos2019-blindness-detection/test_images/95c3558dc279.png
#   inflating: /content/aptos2019-blindness-detection/test_images/95dafd1d5f47.png
#   inflating: /content/aptos2019-blindness-detection/test_images/95e13f31b451.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9600b8ad9d49.png
#   inflating: /content/aptos2019-blindness-detection/test_images/96261748266e.png
#   inflating: /content/aptos2019-blindness-detection/test_images/96602edec13c.png
#   inflating: /content/aptos2019-blindness-detection/test_images/967b01064b9c.png
#   inflating: /content/aptos2019-blindness-detection/test_images/96a3a01f0522.png
#   inflating: /content/aptos2019-blindness-detection/test_images/96a8532d5bc5.png
#   inflating: /content/aptos2019-blindness-detection/test_images/96c199f2afcb.png
#   inflating: /content/aptos2019-blindness-detection/test_images/96c21d31212c.png
#   inflating: /content/aptos2019-blindness-detection/test_images/96c3445bf5cd.png
#   inflating: /content/aptos2019-blindness-detection/test_images/97168872e4de.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9730d08edebd.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9772f0ba0ee7.png
#   inflating: /content/aptos2019-blindness-detection/test_images/978eaa69ae93.png
#   inflating: /content/aptos2019-blindness-detection/test_images/97c4f207ae56.png
#   inflating: /content/aptos2019-blindness-detection/test_images/97cc3916d882.png
#   inflating: /content/aptos2019-blindness-detection/test_images/97f6cff9be9d.png
#   inflating: /content/aptos2019-blindness-detection/test_images/980b5ca190ce.png
#   inflating: /content/aptos2019-blindness-detection/test_images/981115ef58ed.png
#   inflating: /content/aptos2019-blindness-detection/test_images/983b3a401c9e.png
#   inflating: /content/aptos2019-blindness-detection/test_images/983f2756d8be.png
#   inflating: /content/aptos2019-blindness-detection/test_images/987f80393a5a.png
#   inflating: /content/aptos2019-blindness-detection/test_images/989379d3303a.png
#   inflating: /content/aptos2019-blindness-detection/test_images/98b2af334295.png
#   inflating: /content/aptos2019-blindness-detection/test_images/98b46d9f4731.png
#   inflating: /content/aptos2019-blindness-detection/test_images/98c2c42a0317.png
#   inflating: /content/aptos2019-blindness-detection/test_images/98c3ff1b4001.png
#   inflating: /content/aptos2019-blindness-detection/test_images/98e2a0c2238d.png
#   inflating: /content/aptos2019-blindness-detection/test_images/98f7c1cefa4b.png
#   inflating: /content/aptos2019-blindness-detection/test_images/990c506d8de0.png
#   inflating: /content/aptos2019-blindness-detection/test_images/995eb7091756.png
#   inflating: /content/aptos2019-blindness-detection/test_images/99b0bee3bca7.png
#   inflating: /content/aptos2019-blindness-detection/test_images/99b5603c3ddd.png
#   inflating: /content/aptos2019-blindness-detection/test_images/99b6b8ecbcfa.png
#   inflating: /content/aptos2019-blindness-detection/test_images/99c6cf808e47.png
#   inflating: /content/aptos2019-blindness-detection/test_images/99fe5175a56f.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9a33293f90b5.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9a36c6d23fe8.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9a514aa26e2f.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9a7e2e8fa01a.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9a9091fd7806.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9aaf74b298c2.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9ae71f3f62d1.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9b325a96f41a.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9b4b809730ec.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9b5f62614c14.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9b9907171049.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9baaa9117adb.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9bd683e16325.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9c27b212d50b.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9c2c32cbda5a.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9c5ba656e978.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9c73a69a7911.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9cd7e434aa47.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9d19500e74c9.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9d2327e95076.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9d3000de91bd.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9d5061ccc54c.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9d71c73256a8.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9d9de8c9afb5.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9db8a8b68de9.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9df628dd2d68.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9eabe2bdf1e9.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9eac62719123.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9ec84fe4292a.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9ed194d1942c.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9ede102f5e7b.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9efba19d237c.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9f124cfb3f5d.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9f1af957139f.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9f2317a63b63.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9f2539320e85.png
#   inflating: /content/aptos2019-blindness-detection/test_images/9f3457c79515.png
# ...
#   inflating: /content/aptos2019-blindness-detection/train_images/f0c13be90519.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f0e1201b5c1f.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f0f89314e860.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f18abfa690ab.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f1979147aad4.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f1a761c68559.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f1d719c97838.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f1dc26c4bfa3.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f2094a20b275.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f233638e0e90.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f23902998c21.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f252046c0fe6.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f26b02ead915.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f298b7d05958.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f2c0b41acd05.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f2d2a0c92034.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f2ee81781411.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f2f569a64949.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f30f203ef51e.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f35d80bb1a22.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f361060eda3e.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f366fb1cc475.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f36cb007a1ef.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f3a268d2726d.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f3a4751af42e.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f3a88d3026dc.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f3b27ac2d371.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f3b6b7ca1eb1.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f3bb996b45ce.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f3cd489acbee.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f42b693a9414.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f431f2e119d7.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f451eee2b66b.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f45f1485c940.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f460608cf4cc.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f47a2a4a0411.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f481f76a6b75.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f48241b0c995.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f4874247ede6.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f4c7ae514c54.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f4d3169b468a.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f4d3777f2710.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f4de9620e3f2.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f4df3d86688d.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f4e68b61f480.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f4ea2a2cfbb9.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f531232ecb55.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f549294e12e1.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f55e1d2a19e4.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f5650eb52640.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f56ff0440ed1.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f5733f77273d.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f576e45d1da2.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f57cf3b6f48e.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f580566e27f5.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f583a722434c.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f58cdfa968be.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f58d37d48e42.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f58f0b2fd718.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f5a8c6426a71.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f5c953bee7cd.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f5e6226bd2e0.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f5e9a307288c.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f61bf44c677c.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f62b8a076833.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f633c474e8b8.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f64214bed40e.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f64b6e85f1c9.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f66c4ee86629.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f68690db78d3.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f69400b316a7.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f69835dc7c50.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f6d760566a51.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f6f3ea0d2693.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f6f433f3306f.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f6f7dba7104d.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f7116e7b2f4e.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f71333204618.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f71aca5a7dc3.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f71bea807c96.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f72adcac5638.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f72ef9ceeaa8.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f7508f14dd7b.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f762c272c522.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f7735b6d47f7.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f7defe70afc3.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f7e9fa75c7c1.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f7edc074f06b.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f7fec8935126.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f80118bbda18.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f819c65b803c.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f8372e80f731.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f850cb51fdba.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f85c78201a50.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f85fd4fac887.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f86d1c404acb.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f8cf7ed8ef00.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f8d62557ad0c.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f8f5942b690e.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f8fc411092c7.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f901d460517c.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f90f8931a9bc.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f9156aeffc5e.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f91cfa82b9d4.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f920ccd926db.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f952ad2e4356.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f994a3b07935.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f999c6921e6d.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f9aa35187bf3.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f9d52509c571.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f9d8ff3e6592.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f9e1c439d4c8.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f9e779a13204.png
#   inflating: /content/aptos2019-blindness-detection/train_images/f9ecf1795804.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fa0c87bd75ce.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fa3e544a7401.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fa573163dd8b.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fa59221cf464.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fa6f3d8bb1d5.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fa748b57262b.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fa7fa797c650.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fa9bece586fc.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fa9f1bc03f21.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fac399455195.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fb1b8771c70a.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fb61230b99dd.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fb696a8e055a.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fb6b8200b7f8.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fb767cea406c.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fb88783de055.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fb88d23fc5fe.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fba493e17448.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fbcbc81cf9be.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fbdc796290d4.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fbfa925506f6.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fc1b1841eadf.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fc4c2d35c6f8.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fc4d69128e7c.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fc603cbedb41.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fc782722a50c.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fc898dfeb24f.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fc8fce67fbf8.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fca1a8738b8a.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fca931da5c5e.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fcc32dffd24d.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fcc55ae641ae.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fcc6aa6755e6.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fce73678f650.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fce93caa4758.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fd079d2e93a2.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fd0a70082e7c.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fd48cf452e9d.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fd4c946c52bf.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fd62bd0db4f1.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fd87b6b2e664.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fda39982a810.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fdbc252813b1.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fdc685055659.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fdd18ccbbdc5.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fdd534271f3d.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fe06dad6851c.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fe0e2dee1834.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fe0fc67c7980.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fe2df69676cf.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fe37f4492920.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fe3b0e50be78.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fe3f62695b2d.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fe674c2f73f5.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fea14b3d44b0.png
#   inflating: /content/aptos2019-blindness-detection/train_images/febfb20dc311.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fecf4c5ae84b.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fed5bb685832.png
#   inflating: /content/aptos2019-blindness-detection/train_images/fefded6bf135.png
#   inflating: /content/aptos2019-blindness-detection/train_images/ff03f74667df.png
#   inflating: /content/aptos2019-blindness-detection/train_images/ff0740cb484a.png
#   inflating: /content/aptos2019-blindness-detection/train_images/ff1e940105f9.png
#   inflating: /content/aptos2019-blindness-detection/train_images/ff344e5c9341.png
#   inflating: /content/aptos2019-blindness-detection/train_images/ff4832d55461.png
#   inflating: /content/aptos2019-blindness-detection/train_images/ff4955e76894.png
#   inflating: /content/aptos2019-blindness-detection/train_images/ff4cd992667b.png
#   inflating: /content/aptos2019-blindness-detection/train_images/ff52392372d3.png
#   inflating: /content/aptos2019-blindness-detection/train_images/ff59d44a70a7.png
#   inflating: /content/aptos2019-blindness-detection/train_images/ff631653374e.png
#   inflating: /content/aptos2019-blindness-detection/train_images/ff77e8e5b5f3.png
#   inflating: /content/aptos2019-blindness-detection/train_images/ff8a0b45c789.png
#   inflating: /content/aptos2019-blindness-detection/train_images/ffa47f6a7bf4.png
#   inflating: /content/aptos2019-blindness-detection/train_images/ffc04fed30e6.png
#   inflating: /content/aptos2019-blindness-detection/train_images/ffcf7b45f213.png
#   inflating: /content/aptos2019-blindness-detection/train_images/ffd97f8cd5aa.png
#   inflating: /content/aptos2019-blindness-detection/train_images/ffec9a18a3ce.png

# %%
data_dir = "./aptos2019-blindness-detection/"
print(os.listdir("./aptos2019-blindness-detection"))
# Out:
# ['train.csv', 'sample_submission.csv', 'train_images', 'test.csv', 'test_images', '.ipynb_checkpoints']

# %%
train_csv = pd.read_csv('./aptos2019-blindness-detection/train.csv')
test_csv = pd.read_csv('./aptos2019-blindness-detection/test.csv')

# %%
print('Train Size = {}'.format(len(train_csv)))
print('Public Test Size = {}'.format(len(test_csv)))
# Out:
# Train Size = 3662
# Public Test Size = 1928

# %%
train_csv.head()
# Out:
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  001639a390f0          4
# 2  0024cdab0c1e          1
# 3  002c21358ce6          0
# 4  005b95c28852          0

# %%
test_csv.head()
# Out:
#         id_code
# 0  0005cfc8afb6
# 1  003f0afdcd15
# 2  006efc72b638
# 3  00836aaacf06
# 4  009245722fa4

# %%
test_csv['diagnosis'] = -1

# %%
test_csv.head()
# Out:
#         id_code  diagnosis
# 0  0005cfc8afb6         -1
# 1  003f0afdcd15         -1
# 2  006efc72b638         -1
# 3  00836aaacf06         -1
# 4  009245722fa4         -1

# %%
import warnings 

warnings.filterwarnings('ignore')

# %%
import seaborn as sns

counts = train_csv['diagnosis'].value_counts()
class_list = ['No DR', 'Mild', 'Moderate', 'Severe', 'Proliferate']
for i,x in enumerate(class_list):
    counts[x] = counts.pop(i)

plt.figure(figsize=(12,6))
sns.barplot(counts.index, counts.values, alpha=1, palette='deep')
plt.title('Distribution of Output Classes')
plt.ylabel('Number of Occurrences', fontsize=14)
plt.xlabel('Target Classes', fontsize=14)
plt.show()

# %% [markdown]
# ## Visualizing Training Data

# %%
fig = plt.figure(figsize=(30, 16))
# display 20 images
train_imgs = os.listdir(data_dir+"/train_images")
for idx, img in enumerate(np.random.choice(train_imgs, 20)):
    ax = fig.add_subplot(2, 20//2, idx+1, xticks=[], yticks=[])
    im = Image.open(data_dir+"/train_images/" + img)
    plt.imshow(im)
    lab = train_csv.loc[train_csv['id_code'] == img.split('.')[0], 'diagnosis'].values[0]
    ax.set_title('Severity: %s'%lab)

# %% [markdown]
# ## Data Preprocessing

# %%
# Data transforms (normalization & data augmentation)
stats = ((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
train_tfms = tt.Compose([tt.ToPILImage(mode='RGB'),
                         tt.Resize((224, 224)),
                         tt.RandomHorizontalFlip(),
                         tt.ToTensor(), 
                         tt.Normalize(*stats,inplace=True)])

valid_tfms = tt.Compose([tt.ToPILImage(mode='RGB'),
                         tt.Resize((224, 224)),
                         tt.ToTensor(),
                         tt.Normalize(*stats)])

# %%
# Our own custom class for datasets

from torch.utils.data import Dataset

class CreateDataset(Dataset):
    def __init__(self, df_data, data_dir = '../input/', transform=None):
        super().__init__()
        self.df = df_data.values
        self.data_dir = data_dir
        self.transform = transform

    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, index):
        img_name,label = self.df[index]
        img_path = os.path.join(self.data_dir, img_name+'.png')
        image = cv2.imread(img_path)
        if self.transform is not None:
            image = self.transform(image)
        return image, label

# %%
train_path = "./aptos2019-blindness-detection/train_images/"
test_path = "./aptos2019-blindness-detection/test_images/"

# %%
train_data = CreateDataset(df_data=train_csv, data_dir=train_path, transform=train_tfms)
test_data = CreateDataset(df_data=test_csv, data_dir=test_path, transform=valid_tfms)

# %%
# Percentage of training set to use as validation
valid_size = 0.15

# obtain training indices that will be used for validation
num_train = len(train_data)
indices = list(range(num_train))
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# Create Samplers
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# %%
batch_size = 8

# %%
# PyTorch data loaders
train_dl = DataLoader(train_data, batch_size, sampler=train_sampler)
valid_dl = DataLoader(train_data, batch_size, sampler=valid_sampler)

# %%
len(train_dl)
# Out:
# 390

# %%
len(valid_dl)
# Out:
# 69

# %% [markdown]
# ## Define Model Architecture

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %% [markdown]
# Based on where you're running this notebook, your default device could be a CPU (`torch.device('cpu')`) or a GPU (`torch.device('cuda')`)

# %%
device = get_default_device()
device
# Out:
# device(type='cuda')

# %% [markdown]
# We can now wrap our training and validation data loaders using `DeviceDataLoader` for automatically transferring batches of data to the GPU.

# %%
train_dl = DeviceDataLoader(train_dl, device)
valid_dl = DeviceDataLoader(valid_dl, device)

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

class ImageClassificationBase(nn.Module):
    def training_step(self, batch):
        images, labels = batch 
        out = self(images)                  # Generate predictions
        loss = nn.SmoothL1Loss()(out, labels.float()) # Calculate loss
        return loss
    
    def validation_step(self, batch):
        images, labels = batch 
        out = self(images)                    # Generate predictions
        loss = nn.SmoothL1Loss()(out, labels.float())   # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'val_loss': loss.detach(), 'val_acc': acc}
        
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], last_lr: {:.5f}, train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['lrs'][-1], result['train_loss'], result['val_loss'], result['val_acc']))

# %%
class BlindnessDetectorModel(ImageClassificationBase):
    def __init__(self, pretrained=False):
        super().__init__()
        # Use a pretrained model
        self.network = models.resnet152(pretrained=pretrained)
        # Replace last layer
        self.network.fc = nn.Sequential(
                nn.Linear(in_features=2048, out_features=1024, bias=True),
                nn.ReLU(),
                nn.Linear(in_features=1024, out_features=512, bias=True),
                nn.ReLU(),
                nn.Linear(in_features=512, out_features=256, bias=True),
                nn.ReLU(),
                nn.Linear(in_features=256, out_features=128, bias=True),
                nn.ReLU(),
                nn.Linear(in_features=128, out_features=32, bias=True),
                nn.ReLU(),
                nn.Linear(in_features=32, out_features=1, bias=True), 
            )

    def forward(self, xb):
        return self.network(xb)

# %%
model = to_device(BlindnessDetectorModel(), device)
model
# Out:
# BlindnessDetectorModel(
#   (network): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (6): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (7): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (6): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (7): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (8): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (9): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (10): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (11): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (12): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (13): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (14): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (15): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (16): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (17): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (18): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (19): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (20): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (21): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (22): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (23): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (24): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (25): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (26): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (27): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (28): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (29): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (30): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (31): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (32): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (33): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (34): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (35): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Sequential(
#       (0): Linear(in_features=2048, out_features=1024, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=1024, out_features=512, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=512, out_features=256, bias=True)
#       (5): ReLU()
#       (6): Linear(in_features=256, out_features=128, bias=True)
#       (7): ReLU()
#       (8): Linear(in_features=128, out_features=32, bias=True)
#       (9): ReLU()
#       (10): Linear(in_features=32, out_features=1, bias=True)
#     )
#   )
# )

# %%
@torch.no_grad()
def evaluate(model, val_loader):
    model.eval()
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

def fit_one_cycle(epochs, max_lr, model, train_loader, val_loader, 
                  weight_decay=0, grad_clip=None, opt_func=torch.optim.SGD):
    torch.cuda.empty_cache()
    history = []
    
    # Set up cutom optimizer with weight decay
    optimizer = opt_func(model.parameters(), max_lr, weight_decay=weight_decay)
    # Set up one-cycle learning rate scheduler
    sched = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr, epochs=epochs, 
                                                steps_per_epoch=len(train_loader))
    
    for epoch in range(epochs):
        # Training Phase 
        model.train()
        train_losses = []
        lrs = []
        for batch in train_loader:
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()
            
            # Gradient clipping
            if grad_clip: 
                nn.utils.clip_grad_value_(model.parameters(), grad_clip)
            
            optimizer.step()
            optimizer.zero_grad()
            
            # Record & update learning rate
            lrs.append(get_lr(optimizer))
            sched.step()
        
        # Validation phase
        result = evaluate(model, val_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        result['lrs'] = lrs
        model.epoch_end(epoch, result)
        history.append(result)
    return history

# %%
history = [evaluate(model, valid_dl)]
history
# Out:
# [{'val_acc': 0.457608699798584, 'val_loss': 2335.416259765625}]

# %%
epochs = 8
max_lr = 0.01
grad_clip = 0.1
weight_decay = 1e-4
opt_func = torch.optim.Adam

# %%
# %%time
history = fit_one_cycle(epochs, max_lr, model, train_dl, valid_dl, 
                             grad_clip=grad_clip, 
                             weight_decay=weight_decay, 
                             opt_func=opt_func)
# Out:
# Epoch [0], last_lr: 0.00395, train_loss: 0.6819, val_loss: 0.6770, val_acc: 0.4598
# Epoch [1], last_lr: 0.00936, train_loss: 0.6642, val_loss: 0.6777, val_acc: 0.4587
# Epoch [2], last_lr: 0.00972, train_loss: 0.6560, val_loss: 0.6746, val_acc: 0.4587
# Epoch [3], last_lr: 0.00812, train_loss: 0.6575, val_loss: 0.6760, val_acc: 0.4598
# Epoch [4], last_lr: 0.00556, train_loss: 0.6543, val_loss: 0.6814, val_acc: 0.4587
# Epoch [5], last_lr: 0.00283, train_loss: 0.6543, val_loss: 0.6821, val_acc: 0.4587
# Epoch [6], last_lr: 0.00077, train_loss: 0.6530, val_loss: 0.6790, val_acc: 0.4587
# Epoch [7], last_lr: 0.00000, train_loss: 0.6524, val_loss: 0.6809, val_acc: 0.4598
# CPU times: user 49min 5s, sys: 5min 23s, total: 54min 28s
# Wall time: 55min 59s

# %%
def plot_accuracy(history):
    acuuracies = [x['val_acc'] for x in history]
    plt.plot(acuuracies, '-x')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Accuracy vs. No. of epochs');

# %%
plot_accuracy(history)

# %% [markdown]
# We can also plot the training and validation losses to study the trend.

# %%
def plot_losses(history):
    train_losses = [x.get('train_loss') for x in history]
    val_losses = [x['val_loss'] for x in history]
    plt.plot(train_losses, '-bx')
    plt.plot(val_losses, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs. No. of epochs');

# %%
plot_losses(history)

# %% [markdown]
# As expected, the learning rate starts at a low value, and gradually increases for 30% of the iterations to a maximum value of `0.01`, and then gradually decreases to a very small value.

# %% [markdown]
# ## Testing with individual images
#
# While we have been tracking the overall accuracy of a model so far, it's also a good idea to look at model's results on some sample images. Let's test out our model with some images from the predefined test dataset of 10000 images.

# %%
 def round_off_preds(preds, coef=[0.5, 1.5, 2.5, 3.5]):
    for i, pred in enumerate(preds):
            if pred < coef[0]:
                preds[i] = 0
            elif pred >= coef[0] and pred < coef[1]:
                preds[i] = 1
            elif pred >= coef[1] and pred < coef[2]:
                preds[i] = 2
            elif pred >= coef[2] and pred < coef[3]:
                preds[i] = 3
            else:
                preds[i] = 4
    return preds

# %%
class_list = ['No DR', 'Mild', 'Moderate', 'Severe', 'Proliferate']

# %%
def predict_single_image(img, model):
    # Convert to a batch of 1
    xb = to_device(img.unsqueeze(0), device)
    # Get predictions from model
    yb = model(xb)
    preds = int(round_off_preds(yb))
    # Retrieve the class label
    return class_list[preds]

# %%
img, label = test_data[0]
plt.imshow(img.permute(1, 2, 0).clamp(0, 1))
print('Predicted:', predict_single_image(img, model))
# Out:
# Predicted: Mild

# %%
def predict(testloader):
    '''Function used to make predictions on the test set'''
    model.eval()
    preds = []
    for batch_i, (data, target) in enumerate(testloader):
        data, target = data.cuda(), target.cuda()
        output = model(data)
        pr = output.detach().cpu().numpy()
        for i in pr:
            preds.append(i.item())
            
    return preds

# %%
test_dl = DataLoader(test_data, batch_size)

# %%
preds = np.array(predict(testloader=test_dl))

# %%
preds = round_off_preds(preds)

# %% [markdown]
# ## Saving Predictions

# %%
sample_sub = pd.read_csv('aptos2019-blindness-detection/sample_submission.csv')

# %%
sample_sub.diagnosis = preds
sample_sub.diagnosis = sample_sub['diagnosis'].astype(int)

# %%
sample_sub.head()
# Out:
#         id_code  diagnosis
# 0  0005cfc8afb6          1
# 1  003f0afdcd15          1
# 2  006efc72b638          1
# 3  00836aaacf06          1
# 4  009245722fa4          1

# %%
sample_sub.to_csv('submission.csv', index=False)

# %% [markdown]
# ## Save and Commit
#
# Let's save the weights of the model, record the hyperparameters, and commit our experiment to Jovian. As you try different ideas, make sure to record every experiment so you can look back and analyze the results.

# %%
torch.save(model.state_dict(), 'blindness-detector-resnet152.pth')

# %%
# !pip install jovian --upgrade --quiet
# Out:
#      |████████████████████████████████| 71kB 7.7MB/s
#   Building wheel for uuid (setup.py) ... done

# %%
import jovian

# %%
jovian.reset()
jovian.log_hyperparams(arch='resnet152', 
                       epochs=epochs, 
                       lr=max_lr, 
                       scheduler='one-cycle', 
                       weight_decay=weight_decay, 
                       grad_clip=grad_clip,
                       opt=opt_func.__name__)
# Out:
# [jovian] Please enter your API key ( from https://jovian.ai/ ):
# API KEY: ··········
# [jovian] Hyperparams logged.

# %%
train_time = '55:59'

# %%
jovian.log_metrics(val_loss=history[-1]['val_loss'], 
                   val_acc=history[-1]['val_acc'],
                   train_loss=history[-1]['train_loss'],
                   time=train_time)
# Out:
# [jovian] Metrics logged.

# %%
project_name = 'Blindness-Detection-ResNet152'

# %%
jovian.commit(project=project_name, outputs=['blindness-detection-resnet152.pth'])
# Out:
# [jovian] Detected Colab notebook...
# [jovian] Error: jovian.commit doesn't work on Colab unless the notebook was created and executed from Jovian.
# Make sure to run the first code cell at the top after executing from Jovian.
# Alternatively, you can download this notebook and upload it manually to Jovian.
# Learn more: https://jovian.ai/docs/user-guide/run.html#run-on-colab
